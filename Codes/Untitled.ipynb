# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("D:\Machine Learning A-Z™ Python & R in Data Science2023\Gold Price Prediction\Dataset\gold_price.csv")
X = dataset.iloc[:, [1, 3, 4, 5]].values
y = dataset.iloc[:, [2]].values

# %%
dataset.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
dataset.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3
# Out:
#   Cell In[26], line 2
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3
#                                                                                                ^
# SyntaxError: incomplete input

# %%
print(X_train)
print(y_train)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100)
regressor.fit(X_train, y_train)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11396\2221230435.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X_train, y_train)
# RandomForestRegressor()

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[127.08 128.79]
#  [116.88 115.62]
#  [139.61 139.22]
#  [122.37 120.93]
#  [ 94.15  93.04]
#  [154.8  154.65]
#  [117.56 116.72]
#  [113.27 113.03]
#  [153.34 149.74]
#  [105.55 104.8 ]
#  [103.2  103.71]
#  [120.13 119.66]
#  [ 92.37  91.18]
#  [158.65 159.67]
#  [121.57 121.63]
#  [117.5  116.43]
#  [ 86.75  88.95]
#  [ 91.93  91.61]
#  [ 93.04  93.27]
#  [125.46 127.85]
#  [ 82.59  79.2 ]
#  [117.5  118.47]
#  [126.2  126.34]
#  [172.88 175.78]
#  [169.65 174.58]
#  [139.61 138.54]
#  [114.42 114.1 ]
#  [159.76 160.46]
#  [133.7  134.83]
#  [115.64 113.83]
#  [111.26 110.47]
#  [104.98 105.49]
#  [128.05 128.68]
#  [122.07 122.76]
#  [ 99.14  97.7 ]
#  [120.   122.29]
#  [ 83.63  85.07]
#  [115.01 115.47]
#  [127.6  128.38]
#  [140.46 139.26]
#  [107.54 103.92]
#  [131.49 127.93]
#  [108.47 108.32]
#  [135.11 134.37]
#  [133.5  134.18]
#  [149.06 147.63]
#  [119.53 119.82]
#  [155.72 159.46]
#  [155.7  157.7 ]
#  [127.7  127.6 ]
#  [123.96 123.32]
#  [115.   114.87]
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.989279241450708

# %%
y_test = list(y_test)

# %%
plt.plot(y_test, color = 'red', label = 'Original Values', linewidth = '1')
plt.plot(y_pred, color = 'blue', label = 'Predicted Values', linewidth = '1')
plt.title("Original vs Predicted Gold Price")
plt.xlabel("Number of Values")
plt.ylabel("Gold Price(GLD)")
plt.legend()
plt.show()
